# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
X, y = digits["data"], digits["target"]

# %%
from openTSNE import TSNE

embedding = TSNE().fit(X)
# Out:
# /Users/vinhtrongtruong/py_dev/tensorflow/lib/python3.6/site-packages/openTSNE/nearest_neighbors.py:184: UserWarning: `pynndescent` has recently changed which distance metrics are supported, and `openTSNE.nearest_neighbors` has not been updated. Please notify the developers of this change.
#   "`pynndescent` has recently changed which distance metrics are supported, "

# %%
embedding[:5]
# Out:
# TSNEEmbedding([[ -3.22798247,  43.88006625],
#                [  9.7429717 ,  -9.96461332],
#                [ -9.1474121 , -16.67288394],
#                [-29.63495856,   4.86387426],
#                [ 34.26792308,  -5.1420329 ]])

# %%
target_ids = range(len(digits.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(embedding[y == i, 0], embedding[y == i, 1], c=c, label=label)
plt.legend()
plt.show()
